# %%
a = "Ramesh"
print(a[4]+a[1:6])
# print('s'+a[1:])
# Out:
# samesh

# %%
a = "  Khushi"
print(a.lstrip())
# Out:
# Khushi

# %%
a = " Khushi "
print(a.strip())
print(a.rstrip())
print(a.lstrip())
# Out:
# Khushi
#  Khushi
# Khushi

# %%
a = "my name is khushi"
print(a.capitalize())
# Out:
# My name is khushi

# %%
a = "kHUSHI kHANZODE"
print(a.swapcase())
# Out:
# Khushi Khanzode

# %%
a = "KHUSHI"
print(a.startswith('K'))
print(a.endswith('K'))
# Out:
# True
# False

# %%
a = "KHUSHI"
print(a.startswith('K'))
print(a.endswith('K'))
# Out:
# True
# False

# %%
a = "Python"
print(a.find('P'))
# Out:
# 0

# %%
a = "Python"
print(a.index('P'))
# Out:
# 0

# %%
a = "data science"
print(a.find('science'))
print(a.index('data'))
# Out:
# 5
# 0

# %%
a = "Python"
print(a.split('t'))
# Out:
# ['Py', 'hon']

# %%
a = "Doxpro robotics"
print(a.split('t'))
# Out:
# ['Doxpro robo', 'ics']

# %%
a = "Doxpro robotics"
print(a.split( ))#convert string list
# Out:
# ['Doxpro', 'robotics']

# %%
a = ['Doxpro' ,'robotics']
str(a)
print(a)
# Out:
# ['Doxpro', 'robotics']

# %%
a = ['Doxpro' ,'robotics']
b = 'd'.join(a) #Convert list to string
print(b)
# Out:
# Doxprodrobotics

# %%
#its remove starting string
url = "https://www.kaggle.com/login"
new_url = url.removeprefix('https://')
print(new_url)
# Out:
# www.kaggle.com/login

# %%
#its remove ending string

url = "kaggle.com"
new_url = url.removesuffix('.com')
print(new_url)
# Out:
# kaggle

# %%
a = "Data science with python"
print(a.replace(' ','-'))
# Out:
# Data-science-with-python

# %%
a = "Data science with python"
c= a.split(' ')
b = '-'.join(c)
print(b)
# Out:
# Data-science-with-python

# %%
#inquiry method
a = "khushi"

print(a.isupper())
print(a.islower())
print(a.isalnum())
# Out:
# False
# True
# True

# %%
url = input("Enter a url") #https://www.kaggle.com/login
ne= url.split('/')

print("protocol:",ne[0])
print("domain:",ne[2])

print("page:",ne[3])
# Out:
# protocol: https:
# domain: www.kaggle.com
# page: login

# %%
a = "Python"
b = a.rjust(10,'*')
print(b)
# Out:
# ****Python

# %%
a = "banana"
print(a.count('na'))
# Out:
# 2

# %%
url = input("Enter a url") #https://www.kaggle.com/login
ne= url.split('/')

a = ne[0]
print("protocol: ",a.rjust(14,' '))
b = ne[2]
print("domain: ",b.rjust(24,' '))
c = ne[3]

print("page: ",c.rjust(17,' '))
# Out:
# protocol:          https:
# domain:            www.kaggle.com
# page:              login
